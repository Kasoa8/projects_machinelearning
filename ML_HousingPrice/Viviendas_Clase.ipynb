# %%
## SET UP ##
# 1: Importamos las librerias que vamos a usar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir(r"C:\Users\carle\Desktop\3_Estudis\3_Nuclio\Nuclio_Projects")
  # Replace with the actual path to your project directory

# %%
# 2: Importamos el fichero inicial
df_viviendas = pd.read_csv("0_Data/viviendas_regresion_basica.csv")

# %%
## ANALISIS INICIAL ##
df_viviendas.info()

df_viviendas.head()

# %%
df_viviendas[df_viviendas.duplicated()].count()
# Out:
# id_vivienda    0
# superficie     0
# num_hab        0
# distancia      0
# fecha_const    0
# parking        0
# premiada       0
# tam_buzon      0
# precio         0
# impuestos      0
# vendida        0
# dtype: int64

# %%
df_viviendas.isnull().sum()
# Out:
# id_vivienda       0
# superficie       10
# num_hab           0
# distancia         0
# fecha_const       0
# parking        2239
# premiada          0
# tam_buzon         0
# precio            3
# impuestos         3
# vendida           3
# dtype: int64

# %%
df_viviendas.nunique()
# Out:
# id_vivienda    7003
# superficie       71
# num_hab           4
# distancia        10
# fecha_const      60
# parking           2
# premiada          2
# tam_buzon        16
# precio          241
# impuestos       241
# vendida           2
# dtype: int64

# %%
df_viviendas['distancia'].unique()
# Out:
# array([ 7,  8,  4,  1,  5, 10,  3,  2,  6,  9], dtype=int64)

# %%
df_predecir = df_viviendas.tail(3)
df_predecir
# Out:
#      id_vivienda  superficie num_hab  distancia fecha_const parking  premiada  \
# 7000    viv_7001       128.0       3          6  2022-01-01     ext         0
# 7001    viv_7002        93.0      4+          9  1988-01-01     NaN         0
# 7002    viv_7003        68.0       2          3  1972-01-01     NaN         0
#
#       tam_buzon  precio  impuestos  vendida
# 7000        0.7     NaN        NaN      NaN
# 7001        1.5     NaN        NaN      NaN
# 7002        0.7     NaN        NaN      NaN

# %%
df = df_viviendas.head(7000)
df
# Out:
#      id_vivienda  superficie num_hab  distancia fecha_const parking  premiada  \
# 0          viv_1        65.0       1          7  1991-01-01     ext         0
# 1          viv_2        97.0      4+          8  1994-01-01     ext         0
# 2          viv_3        80.0      4+          4  1970-01-01     NaN         0
# 3          viv_4        73.0       1          1  1983-01-01     ext         0
# 4          viv_5        86.0       2          8  1999-01-01     NaN         0
# ...          ...         ...     ...        ...         ...     ...       ...
# 6995    viv_6996        98.0       2          2  2006-01-01     int         0
# 6996    viv_6997       111.0      4+          2  1981-01-01     ext         0
# 6997    viv_6998        76.0       3          4  2009-01-01     ext         0
# 6998    viv_6999       128.0       3          5  1979-01-01     NaN         0
# 6999    viv_7000        77.0      4+          7  1996-01-01     ext         0
#
# ...

# %%
# queremos entrenar el modelo con esas viviendas que si se han vendido, porque sino llenamos el modelo de falsos datos
df = df[df['vendida']==1]
df = df.drop('vendida', axis=1)
df_predecir = df_predecir.drop('vendida', axis=1)

# %%
# gestión de datos
import numpy as np
import pandas as pd
# fechas
import datetime as dt
from datetime import datetime
from dateutil.relativedelta import relativedelta
# gráficos
import seaborn as sns
import matplotlib.pyplot as plt
# preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# modelos
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
# metricas
import sklearn.metrics as metrics
# hiperparametrizado
from sklearn.model_selection import GridSearchCV
# quitar alertas
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 18
#      16 from sklearn.svm import SVC
#      17 from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
# ---> 18 from xgboost import XGBRegressor
#      19 from catboost import CatBoostRegressor
#      20 # metricas
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
sns.kdeplot(data=df, x='precio')
plt.show()

# %%
sns.scatterplot(data=df, x='superficie', y='precio')
plt.show()
